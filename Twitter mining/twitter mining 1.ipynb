# %% [markdown]
# # Tutorial: Extracting and visualizing twitter data

# %% [markdown]
# Why twitter data? Presents an ideal combination of size, international reach, and data
# accessibility that make it the preferred platform in academic studies.

# %% [markdown]
# # We will do the following
# 1. Create a twitter account or use your existing Twitter account.
# 2. Request for twitter developer access key
# 3. Extract real-time tweets using Twitter Streaming API
# 4. Extract history tweets using Twitter Search/Rest API using Tweepy
# 5. Load the data to a pandas data frame
# 6. Wordcloud

# %% [markdown]
# Steps to request twitter access
# 1. Goto to https://developer.twitter.com/en/apps.
# 2. Log in using your twitter account. If you don’t have one then create one.
# 3. After logged in then create an app.
# 4. Fill out all the required fields.

# %% [markdown]
# # Import the libraries

# %%
import tweepy
import nltk
import pandas as pd
import sys
import csv 
from wordcloud import WordCloud, STOPWORDS
import matplotlib as mpl
import re
from PIL import Image
import json
import twitter
import numpy as np
# import pandas_profiling

# %% [markdown]
# ## Twitter developer keys (Keys are not to be shared)

# %%
# The value inside quotes must be replaced by your keys if you are using this.
api = twitter.Api(consumer_key='ryoIytUyHBiBxK7aIk1H48la8',
                      consumer_secret='Yzc5tDJtf6t8iJvAt6Cq6G4SPatw0AFtpOtwKodLXrNAkqlKjF',
                      access_token_key='382027921-go6DGgjXikmEb1XZqeNYSTh1GzfoMWW4yeIU8FYB',
access_token_secret='OiP1HPILePOIHQLAKoQqkgonvXM31Fil1HTP7BfKpMrP0')

# %% [markdown]
# ## Let's look at some tweets

# %% [markdown]
# Location data - Streaming API

# %%
# Filter by location; some location coordinates-https://gist.github.com/graydon/11198540
# for tweet in api.GetStreamFilter(locations = ['32.5532,0.2944,32.6212,0.3564']): 
for tweet in api.GetStreamFilter(locations = ['33.8935689697,-4.67677,41.8550830926,5.506']):
    print (tweet)
    break
# Out:
# {u'quote_count': 0, u'contributors': None, u'truncated': False, u'text': u'Districts of #Kismayo city\nCALANLEY\nFARJANNO\nFAANOOLE\nSHAQAALAHA\nGUULWADE\n\n#Jubaland #Somalia https://t.co/MI461RKpIX', u'is_quote_status': False, u'in_reply_to_status_id': None, u'reply_count': 0, u'id': 1186251890356568064, u'favorite_count': 0, u'entities': {u'user_mentions': [], u'symbols': [], u'hashtags': [{u'indices': [13, 21], u'text': u'Kismayo'}, {u'indices': [75, 84], u'text': u'Jubaland'}, {u'indices': [85, 93], u'text': u'Somalia'}], u'urls': [], u'media': [{u'expanded_url': u'https://twitter.com/AbdisalamAato/status/1186251890356568064/photo/1', u'display_url': u'pic.twitter.com/MI461RKpIX', u'url': u'https://t.co/MI461RKpIX', u'media_url_https': u'https://pbs.twimg.com/media/EHZpy61WkAAUYHd.jpg', u'id_str': u'1186251875366113280', u'sizes': {u'small': {u'h': 680, u'resize': u'fit', u'w': 510}, u'large': {u'h': 1024, u'resize': u'fit', u'w': 768}, u'medium': {u'h': 1024, u'resize': u'fit', u'w': 768}, u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}}, u'indices': [94, 117], u'type': u'photo', u'id': 1186251875366113280, u'media_url': u'http://pbs.twimg.com/media/EHZpy61WkAAUYHd.jpg'}]}, u'retweeted': False, u'coordinates': None, u'timestamp_ms': u'1571659464812', u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', u'in_reply_to_screen_name': None, u'id_str': u'1186251890356568064', u'display_text_range': [0, 93], u'retweet_count': 0, u'in_reply_to_user_id': None, u'favorited': False, u'user': {u'follow_request_sent': None, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 20003409, u'default_profile': False, u'verified': False, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1182062639507283968/6m_JaxpP_normal.jpg', u'profile_sidebar_fill_color': u'95E8EC', u'profile_text_color': u'3C3940', u'followers_count': 52011, u'profile_sidebar_border_color': u'FFFFFF', u'id_str': u'20003409', u'profile_background_color': u'0099B9', u'listed_count': 81, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme4/bg.gif', u'utc_offset': None, u'statuses_count': 14038, u'description': u'Somali Filmmaker, Storyteller, Father & Creative Consultant.    Contact: AatoStratcom@gmail.com', u'friends_count': 691, u'location': u'Somalia', u'profile_link_color': u'0096FF', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1182062639507283968/6m_JaxpP_normal.jpg', u'following': None, u'geo_enabled': True, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/20003409/1549667903', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme4/bg.gif', u'name': u'Aato', u'lang': None, u'profile_background_tile': False, u'favourites_count': 18047, u'screen_name': u'AbdisalamAato', u'notifications': None, u'url': None, u'created_at': u'Tue Feb 03 20:58:14 +0000 2009', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'translator_type': u'none', u'is_translator': False}, u'geo': None, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'hi', u'created_at': u'Mon Oct 21 12:04:24 +0000 2019', u'filter_level': u'low', u'in_reply_to_status_id_str': None, u'place': {u'full_name': u'Somalia', u'url': u'https://api.twitter.com/1.1/geo/id/2e09439cac5c7992.json', u'country': u'Somalia', u'place_type': u'country', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[40.988668, -1.660362], [40.988668, 11.988069], [51.415496, 11.988069], [51.415496, -1.660362]]]}, u'country_code': u'SO', u'attributes': {}, u'id': u'2e09439cac5c7992', u'name': u'Somalia'}, u'extended_entities': {u'media': [{u'expanded_url': u'https://twitter.com/AbdisalamAato/status/1186251890356568064/photo/1', u'display_url': u'pic.twitter.com/MI461RKpIX', u'url': u'https://t.co/MI461RKpIX', u'media_url_https': u'https://pbs.twimg.com/media/EHZpy61WkAAUYHd.jpg', u'id_str': u'1186251875366113280', u's ...

# %% [markdown]
# ## lets save the json data to a file: stream.json

# %%
# "\n" is new line. We save the data to a file,
# with each new line we save all the information related to one tweet
f = open('./stream0.json', 'w')
for tweet in api.GetStreamFilter(locations = ['32.5532,0.2944,32.6212,0.3564']):
# for tweet in api.GetStreamFilter(locations = ['33.8935689697,-4.67677,41.8550830926,5.506']):
    f.write(json.dumps(tweet))
    f.write('\n') 
#     print (tweet)

# %% [markdown]
# # Reading tweets from the json file

# %%
#Upload the json file and append it to a list
data=[]
with open('./stream1.json', 'r') as jsonFile:
    for line in jsonFile:
        data.append(json.loads(line))
print ("Total number of tweets loaded: ", len(data))
print(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-358ad9f20f58> in <module>()
#       3 with open('./stream1.json', 'r') as jsonFile:
#       4     for line in jsonFile:
# ----> 5         data.append(json.loads(line))
#       6 print ("Total number of tweets loaded: ", len(data))
#       7 print(data)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     364
#     365         """
# --> 366         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     367         end = _w(s, end).end()
#     368         if end != len(s):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     382             obj, end = self.scan_once(s, idx)
#     383         except StopIteration:
# --> 384             raise ValueError("No JSON object could be decoded")
#     385         return obj, end
#
# ValueError: No JSON object could be decoded

# %% [markdown]
# # Check the keys and the tweet itself

# %%
print (data[0].keys())   # properties
# Out:
# [u'quote_count', u'contributors', u'truncated', u'text', u'is_quote_status', u'in_reply_to_status_id', u'reply_count', u'id', u'favorite_count', u'source', u'retweeted', u'coordinates', u'timestamp_ms', u'entities', u'in_reply_to_screen_name', u'in_reply_to_user_id', u'display_text_range', u'retweet_count', u'id_str', u'favorited', u'user', u'geo', u'in_reply_to_user_id_str', u'lang', u'created_at', u'filter_level', u'in_reply_to_status_id_str', u'place']

# %%
# The dictionary consists of a lot of information like created, user ID, retweeted, timestamp, etc. 
# Just read from the dictionary what information you need and then proceed with the text mining and visualization.

# %%
print (data[0]["text"])  # how to access the  tweet message itself
# Out:
# @SarahSolomong Beautiful

# %%
# About the search API or REST API
# Twitter’s Search API gives you access to a data set that already exists from tweets that have occurred. 
# For an individual user, the maximum number of tweets you can receive is the last 3,200 tweets, regardless of the query criteria. 
# With a specific keyword, you can typically only poll the last 5,000 tweets per keyword. 
# You are further limited by the number of requests you can make in a certain time period. 
# The Twitter request limits have changed over the years but are currently limited to 180 requests in a 15 minute period.

# %% [markdown]
# # Extract history tweets using Twitter Search/Rest API using Tweepy

# %% [markdown]
# Extracting the tweets @dsa_org. The maximum tweets allowed is 3200.
# I can’t extract the whole tweet history of the user if they have tweeted more than 3200 tweets.

# %%
consumer_key = "ryoIytUyHBiBxK7aIk1H48la8" 
consumer_secret = "Yzc5tDJtf6t8iJvAt6Cq6G4SPatw0AFtpOtwKodLXrNAkqlKjF"
access_key = "382027921-go6DGgjXikmEb1XZqeNYSTh1GzfoMWW4yeIU8FYB"
access_secret = "OiP1HPILePOIHQLAKoQqkgonvXM31Fil1HTP7BfKpMrP0"
  
    
def get_tweets(username): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
        # Access to user's access key and access secret 
        auth.set_access_token(access_key, access_secret) 
        # Calling api 
        api = tweepy.API(auth) 
        #set count to however many tweets you want - max count is 3200 and this doesn't have any effect if it is more than 3200
        #number_of_tweets = 5000
       
        tfile = []
        for tweet in tweepy.Cursor(api.user_timeline, screen_name = username).items():

        #username, tweet id, date/time, text
            tfile.append([username, tweet.id_str,tweet.source, tweet.created_at,tweet.retweet_count,tweet.favorite_count, tweet.text.encode("utf-8")])

        #write to a new csv file from the array of tweets
        outfile = username + "_tweets_V1.csv"
        print ("writing to " + outfile)
        with open(outfile, 'w+') as file:
            writer = csv.writer(file, delimiter=',')
            writer.writerow(['User_Name', 'Tweet_ID', 'Source', 'Created_date','Retweet_count','Favorite_count','Tweet'])
            writer.writerows(tfile)
# user name
get_tweets("@dsa_org")
# Out:
# writing to @dsa_org_tweets_V1.csv

# %% [markdown]
# # Upload the data into a pandas data frame for data visualization

# %% [markdown]
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types.
# You can think of it like a spreadsheet or SQL table, or a dict of Series objects.
# It is generally the most commonly used pandas object.

# %%
#Read the file and also assign it to dataframe
import pandas as pd
bg= pd.read_csv("@dsa_org_tweets_V1.csv",encoding='utf-8') 
bg.head(10)
# Out:
#   User_Name             Tweet_ID               Source         Created_date  \
# 0  @dsa_org  1186219781785112582      Twitter Web App  2019-10-21 09:56:49
# 1  @dsa_org  1186214576305721345      Twitter Web App  2019-10-21 09:36:08
# 2  @dsa_org  1186211180894924800      Twitter Web App  2019-10-21 09:22:38
# 3  @dsa_org  1186209543853953024      Twitter Web App  2019-10-21 09:16:08
# 4  @dsa_org  1185468445359513600  Twitter for Android  2019-10-19 08:11:16
# 5  @dsa_org  1184867257240956929      Twitter Web App  2019-10-17 16:22:22
# 6  @dsa_org  1176769426282156033      Twitter Web App  2019-09-25 08:04:29
# 7  @dsa_org  1176183765934235650  Twitter for Android  2019-09-23 17:17:16
# 8  @dsa_org  1176183757021351941  Twitter for Android  2019-09-23 17:17:14
# 9  @dsa_org  1174657671045222400      Twitter Web App  2019-09-19 12:13:07
#
#    Retweet_count  Favorite_count  \
# 0              1               6
# 1              3               5
# 2              3               0
# 3              7               0
# 4              7               0
# 5             27              75
# 6             62              67
# 7             24               0
# 8             19               0
# 9              0               2
#
#                                                Tweet
# 0  You can sit in an office in Kampala and still ...
# 1  Data Science Africa is focused on developing l...
# 2  RT @ensoesie: We have participants from at lea...
# 3  RT @ensoesie: First day of Data Science Africa...
# 4  RT @charlesity: In a couple of days we meet ag...
# 5  In 3 days time, we get to catch up with indust...
# 6  We’re seeking mentors for a pilot program to r...
# 7  RT @DataForager: ATTN MENTORS: @dsa_org is see...
# 8  RT @lawrennd: Looking for mentors for @dsa_org...
# 9  @lawrennd @Cambridge_CL @DeepMindAI Congratula...

# %% [markdown]
# # Do some basic cleaning of the tweets

# %%
bg.columns
# Out:
# Index([u'User_Name', u'Tweet_ID', u'Source', u'Created_date', u'Retweet_count',
#        u'Favorite_count', u'Tweet'],
#       dtype='object')

# %%
bg2 = []
# import re
pattern1 = re.compile(" ' # S % & ' ( ) * + , - . / : ; < = >  @ [ / ] ^ _ { | } ~")
pattern2 = re.compile("@[A-Za-z0-9]+") 
pattern3 = re.compile("https?://[A-Za-z0-9./]+")

for i in bg.index:
#     print item
    tweet = bg.iloc[i]['Tweet']
#     print tweet
    tweet = re.sub(pattern1, "", tweet)   # version 1 of the tweet
    tweet = re.sub(pattern2, "", tweet)
    tweet = re.sub(pattern3, "", tweet)
#     print tweet
    bg2.append(tweet.encode('utf-8'))

bg3 = pd.DataFrame(bg2,columns = ['tweet'])

# %% [markdown]
# The re.sub() function in the re module can be used to replace substrings.
# The syntax for re.sub() is re.sub(pattern,repl,string).

# %%
bg3.head(10)
# Out:
#                                                tweet
# 0  You can sit in an office in Kampala and still ...
# 1  Data Science Africa is focused on developing l...
# 2  RT : We have participants from at least 15 Afr...
# 3  RT : First day of Data Science Africa at  Univ...
# 4  RT : In a couple of days we meet again this ti...
# 5  In 3 days time, we get to catch up with indust...
# 6  We’re seeking mentors for a pilot program to r...
# 7  RT : ATTN MENTORS: _org is seeking 3-5 mentors...
# 8  RT : Looking for mentors for _org students. Se...
# 9                             _CL  Congratulations!!

# %% [markdown]
# # Now we can do the visualization

# %% [markdown]
# #WordCloud

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

mpl.rcParams['figure.figsize']=(16.0,10.0)    
mpl.rcParams['font.size']=12                
mpl.rcParams['savefig.dpi']=1400             
mpl.rcParams['figure.subplot.bottom']=.1 

stopwords = set(STOPWORDS)
text = " ".join(tweet for tweet in bg3.tweet)
print ("There are {} words in the combination of all tweets.".format(len(text)))

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(text))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=1400)
# Out:
# There are 5783 words in the combination of all tweets.
# <wordcloud.wordcloud.WordCloud object at 0x15c6b9ad0>

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import urllib
import requests
import numpy as np
import matplotlib.pyplot as plt

mask= np.array(Image.open("bafrica.png"))

words = " ".join(review for review in bg3.tweet)

# This function takes in your text and your mask and generates a wordcloud. 
def generate_wordcloud(words, mask):
    word_cloud = WordCloud(width = 512, height = 512, background_color='white',max_words=3000,stopwords=STOPWORDS, mask=mask,contour_width=1, contour_color='navy' ).generate(words)
    plt.figure(figsize=(14,10),facecolor = 'white', edgecolor='red')
    plt.imshow(word_cloud,interpolation='bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()

#Run the following to generate your wordcloud
generate_wordcloud(str(words), mask)

# %% [markdown]
# Other maaterials
#
# https://towardsdatascience.com/the-next-level-of-data-visualization-in-python-dd6e99039d5e
#
# https://towardsdatascience.com/a-complete-exploratory-data-analysis-and-visualization-for-text-data-29fb1b96fb6a
